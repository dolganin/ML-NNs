# %%
from roboflow import Roboflow
rf = Roboflow(api_key="SPT7DDaKZxvm070M1VMg")
project = rf.workspace("roboflow-gw7yv").project("raccoon")
version = project.version(38)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Raccoon-38 in yolov8:: 100%|██████████| 799/799 [00:00<00:00, 10955.09it/s]

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
results = model.train(data="Raccoon-38/data.yaml", 
                      epochs=100, 
                      imgsz=960, 
                      workers=129, 
                      batch=8, 
                      device=0, 
                      name = "PersonYolo8n_960_1919", 
                      #resume = True,
                      plots = True,
                      exist_ok = True,
                      save_period = 10,
                      #аугментации 
                      translate = 0.5,
                      scale = 0.7,
                      #erasing = 0.9,
                      shear = 30, 
                      #mixup = 0.4,
                      hsv_h = 0.4, 
                      hsv_v = 0.6,
                      #crop_fraction = 0.5
                      #copy_paste = 0.4
                     )
# Out:
# New https://pypi.org/project/ultralytics/8.3.63 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.3.0a0+40ec155e58.nv24.03 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
# ...
